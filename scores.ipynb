# %% [markdown]
# # Importing The Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# * Importing the data

# %%
url = 'https://bit.ly/w-data'
df = pd.read_csv(url)
print('Data Imported Successfully')
df.head(10)
# Out:
# Data Imported Successfully
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %% [markdown]
# * Plotting our data to describe our dataset and see if we can manually find any relationship between the data.

# %%
df.plot(x = 'Hours', y = 'Scores', style = 'o')
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Scored')
plt.show()

# %% [markdown]
# * From the above granp we can clearly depict that there is a positive linear relation between the number of hours and percentage scored.

# %% [markdown]
# # Preparing The Data
#
# * The next step is to divide the data into 'attributes' (inputs) and 'labels' (output).

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, 1].values

# %% [markdown]
# * Now that we have our attributes and labels, the next step is to split this data into training and test sets. We'll do this by using Scikit-Learn's built-in train_test_split() method.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Training The Algorithm

# %% [markdown]
# * We have split our data into training and testing sets, and now is finally time to tarin our model.

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
print('Training Complete.')
# Out:
# Training Complete.

# %% [markdown]
# * Plotting the regression line

# %%
line = regressor.coef_*X+regressor.intercept_

#Plotting for test data
plt.scatter(X, y)
plt.plot(X, line)
plt.show()

# %% [markdown]
# # Making Predictions
#
# * Now that wehave trained our algorithm, it's time to make some predictions.

# %%
print(X_test)  # Testing data - In Hours
y_pred = regressor.predict(X_test)  # Predicting the Scores
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %% [markdown]
# * Comparing Actual vs Predicted

# %%
df1 = pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
df1
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %% [markdown]
# * You can also test with your own data.

# %%
hrs = 9.25
own_pred = regressor.predict([[hrs]])
print('No of Hours = {}'.format(hrs))
print('Predicted Score = {}'.format(own_pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.69173248737535
